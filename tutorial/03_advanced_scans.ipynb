# %%
from bluesky import RunEngine
from bluesky.plans import fly, adaptive_scan
from bluesky.callbacks.best_effort import BestEffortCallback
from ophyd.sim import flyer1, det, motor

# %%
RE = RunEngine()

bec = BestEffortCallback()
RE.subscribe(bec)

# %% [markdown]
# ## Fly Scan

# %%
RE(
    fly([flyer1])
)
# Out:
# Transient Scan ID: 2     Time: 2024-08-26 15:31:42
# Persistent Unique Scan ID: 'baaad7c4-ab75-47de-91f4-788de79a2d3b'
# New stream: 'flyer1'
# ('baaad7c4-ab75-47de-91f4-788de79a2d3b',)

# %% [markdown]
# ## Adaptive Scan

# %%
RE(
    adaptive_scan([det], 'det', motor, start=-1, stop=10, min_step=0.1, max_step=7, target_delta=0.1, backstep=True)
)
# Out:
# ('ffb528c8-7773-43ab-99a9-1108701431c5',)

# %%
RE(
    adaptive_scan([det], 'det', motor, start=-10, stop=10, min_step=0.1, max_step=20, target_delta=0.001, backstep=True)
)
# Out:
# Transient Scan ID: 30     Time: 2024-08-26 15:45:18
# Persistent Unique Scan ID: '73cddf6e-7831-444b-9fbf-71c6c67f5be8'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |         1 | 15:45:18.9 |    -10.000 |      0.000 |
# |         2 | 15:45:19.0 |     -0.050 |      0.999 |
# |         3 | 15:45:19.1 |     -9.900 |      0.000 |
# |         4 | 15:45:19.1 |     -5.820 |      0.000 |
# |         5 | 15:45:19.2 |      1.444 |      0.353 |
# |         6 | 15:45:19.2 |     -5.720 |      0.000 |
# |         7 | 15:45:19.3 |     -1.640 |      0.261 |
# |         8 | 15:45:19.3 |     -5.620 |      0.000 |
# |         9 | 15:45:19.4 |     -1.540 |      0.306 |
# |        10 | 15:45:19.5 |     -5.520 |      0.000 |
# |        11 | 15:45:19.5 |     -1.440 |      0.355 |
# |        12 | 15:45:19.6 |     -5.420 |      0.000 |
# |        13 | 15:45:19.7 |     -1.340 |      0.407 |
# |        14 | 15:45:19.7 |     -5.320 |      0.000 |
# |        15 | 15:45:19.8 |     -1.240 |      0.464 |
# |        16 | 15:45:19.8 |     -5.220 |      0.000 |
# |        17 | 15:45:19.9 |     -1.140 |      0.522 |
# |        18 | 15:45:20.0 |     -5.120 |      0.000 |
# |        19 | 15:45:20.0 |     -1.040 |      0.582 |
# |        20 | 15:45:20.1 |     -5.020 |      0.000 |
# |        21 | 15:45:20.2 |     -0.940 |      0.643 |
# |        22 | 15:45:20.2 |     -4.920 |      0.000 |
# |        23 | 15:45:20.3 |     -0.840 |      0.703 |
# |        24 | 15:45:20.4 |     -4.820 |      0.000 |
# |        25 | 15:45:20.4 |     -0.740 |      0.760 |
# |        26 | 15:45:20.5 |     -4.720 |      0.000 |
# |        27 | 15:45:20.6 |     -1.012 |      0.599 |
# |        28 | 15:45:20.6 |     -4.620 |      0.000 |
# |        29 | 15:45:20.7 |     -2.228 |      0.084 |
# |        30 | 15:45:20.8 |     -4.520 |      0.000 |
# |        31 | 15:45:20.8 |     -2.951 |      0.013 |
# |        32 | 15:45:20.9 |     -4.398 |      0.000 |
# |        33 | 15:45:20.9 |     -3.379 |      0.003 |
# |        34 | 15:45:21.1 |     -4.085 |      0.000 |
# |        35 | 15:45:21.2 |     -3.477 |      0.002 |
# |        36 | 15:45:21.3 |     -3.800 |      0.001 |
# |        37 | 15:45:21.3 |     -3.456 |      0.003 |
# |        38 | 15:45:21.4 |     -3.610 |      0.001 |
# |        39 | 15:45:21.5 |     -3.408 |      0.003 |
# |        40 | 15:45:21.5 |     -3.478 |      0.002 |
# |        41 | 15:45:21.6 |     -3.342 |      0.004 |
# |        42 | 15:45:21.7 |     -3.378 |      0.003 |
# |        43 | 15:45:21.7 |     -3.277 |      0.005 |
# |        44 | 15:45:21.8 |     -3.177 |      0.006 |
# |        45 | 15:45:21.9 |     -3.076 |      0.009 |
# |        46 | 15:45:21.9 |     -2.976 |      0.012 |
# |        47 | 15:45:22.0 |     -2.876 |      0.016 |
# |        48 | 15:45:22.1 |     -2.775 |      0.021 |
# |        49 | 15:45:22.1 |     -2.675 |      0.028 |
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |        50 | 15:45:22.2 |     -2.575 |      0.036 |
# |        51 | 15:45:22.3 |     -2.475 |      0.047 |
# |        52 | 15:45:22.3 |     -2.375 |      0.060 |
# |        53 | 15:45:22.4 |     -2.275 |      0.075 |
# |        54 | 15:45:22.4 |     -2.175 |      0.094 |
# |        55 | 15:45:22.5 |     -2.075 |      0.116 |
# |        56 | 15:45:22.6 |     -1.975 |      0.142 |
# |        57 | 15:45:22.6 |     -1.875 |      0.173 |
# |        58 | 15:45:22.7 |     -1.775 |      0.207 |
# |        59 | 15:45:22.8 |     -1.675 |      0.246 |
# |        60 | 15:45:22.8 |     -1.575 |      0.290 |
# |        61 | 15:45:22.9 |     -1.475 |      0.337 |
# |        62 | 15:45:23.0 |     -1.374 |      0.389 |
# |        63 | 15:45:23.0 |     -1.274 |      0.444 |
# |        64 | 15:45:23.1 |     -1.174 |      0.502 |
# |        65 | 15:45:23.2 |     -1.074 |      0.561 |
# |        66 | 15:45:23.2 |     -0.974 |      0.622 |
# |        67 | 15:45:23.3 |     -0.874 |      0.682 |
# |        68 | 15:45:23.4 |     -0.774 |      0.741 |
# |        69 | 15:45:23.4 |     -0.674 |      0.797 |
# |        70 | 15:45:23.5 |     -0.574 |      0.848 |
# |        71 | 15:45:23.6 |     -0.474 |      0.894 |
# |        72 | 15:45:23.6 |     -0.374 |      0.932 |
# |        73 | 15:45:23.7 |     -0.274 |      0.963 |
# |        74 | 15:45:23.8 |     -0.174 |      0.985 |
# |        75 | 15:45:23.9 |     -0.074 |      0.997 |
# |        76 | 15:45:23.9 |      0.026 |      1.000 |
# |        77 | 15:45:24.0 |      0.126 |      0.992 |
# |        78 | 15:45:24.1 |      0.226 |      0.975 |
# |        79 | 15:45:24.1 |      0.326 |      0.948 |
# |        80 | 15:45:24.2 |      0.426 |      0.913 |
# |        81 | 15:45:24.3 |      0.526 |      0.871 |
# |        82 | 15:45:24.3 |      0.626 |      0.822 |
# |        83 | 15:45:24.4 |      0.726 |      0.769 |
# |        84 | 15:45:24.5 |      0.826 |      0.711 |
# |        85 | 15:45:24.5 |      0.926 |      0.652 |
# |        86 | 15:45:24.6 |      1.026 |      0.591 |
# |        87 | 15:45:24.7 |      1.126 |      0.531 |
# |        88 | 15:45:24.7 |      1.226 |      0.472 |
# |        89 | 15:45:24.8 |      1.326 |      0.415 |
# |        90 | 15:45:24.9 |      1.426 |      0.362 |
# |        91 | 15:45:24.9 |      1.526 |      0.312 |
# |        92 | 15:45:25.0 |      1.626 |      0.267 |
# |        93 | 15:45:25.1 |      1.726 |      0.226 |
# |        94 | 15:45:25.2 |      1.826 |      0.189 |
# |        95 | 15:45:25.3 |      1.926 |      0.157 |
# |        96 | 15:45:25.4 |      2.026 |      0.129 |
# |        97 | 15:45:25.4 |      2.126 |      0.104 |
# |        98 | 15:45:25.5 |      2.226 |      0.084 |
# |        99 | 15:45:25.6 |      2.326 |      0.067 |
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |       100 | 15:45:25.6 |      2.426 |      0.053 |
# |       101 | 15:45:25.7 |      2.526 |      0.041 |
# |       102 | 15:45:25.8 |      2.626 |      0.032 |
# |       103 | 15:45:25.8 |      2.726 |      0.024 |
# |       104 | 15:45:25.9 |      2.826 |      0.018 |
# |       105 | 15:45:26.0 |      2.926 |      0.014 |
# |       106 | 15:45:26.1 |      3.026 |      0.010 |
# |       107 | 15:45:26.1 |      3.126 |      0.008 |
# |       108 | 15:45:26.2 |      3.226 |      0.006 |
# |       109 | 15:45:26.2 |      3.326 |      0.004 |
# |       110 | 15:45:26.3 |      3.426 |      0.003 |
# |       111 | 15:45:26.4 |      3.526 |      0.002 |
# |       112 | 15:45:26.5 |      3.630 |      0.001 |
# |       113 | 15:45:26.5 |      3.746 |      0.001 |
# |       114 | 15:45:26.6 |      3.888 |      0.001 |
# |       115 | 15:45:26.7 |      4.077 |      0.000 |
# |       116 | 15:45:26.7 |      4.366 |      0.000 |
# |       117 | 15:45:26.8 |      4.930 |      0.000 |
# |       118 | 15:45:26.9 |      7.058 |      0.000 |
# +-----------+------------+------------+------------+
# generator adaptive_scan ['73cddf6e'] (scan num: 30)
# ('73cddf6e-7831-444b-9fbf-71c6c67f5be8',)

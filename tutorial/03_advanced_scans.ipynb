# %%
# %matplotlib qt
from bluesky import RunEngine
from bluesky.plans import fly, adaptive_scan
from bluesky.callbacks.best_effort import BestEffortCallback
from ophyd.sim import flyer1, det, motor
from matplotlib.pyplot import ion
from bluesky.utils import install_nb_kicker
install_nb_kicker()

ion()

# %%
RE = RunEngine()

bec = BestEffortCallback()
RE.subscribe(bec)
# Out:
# 0

# %% [markdown]
# ## Fly Scan

# %%
RE(
    fly([flyer1])
)
# Out:
# Transient Scan ID: 1     Time: 2024-08-28 09:32:21
# Persistent Unique Scan ID: '446c2a31-644b-455b-ae4f-08a3a84adaec'
# New stream: 'flyer1'
# ('446c2a31-644b-455b-ae4f-08a3a84adaec',)

# %% [markdown]
# ## Adaptive Scan

# %%
RE(
    adaptive_scan([det], 'det', motor, start=-1, stop=10, min_step=0.1, max_step=7, target_delta=0.1, backstep=True)
)
# Out:
# Transient Scan ID: 8     Time: 2024-08-28 09:33:15
# Persistent Unique Scan ID: 'a35600cf-06dc-41c0-8dec-305819b8addb'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |         1 | 09:33:15.5 |     -1.000 |      0.607 |
# |         2 | 09:33:15.5 |      2.450 |      0.050 |
# |         3 | 09:33:15.5 |     -0.380 |      0.930 |
# |         4 | 09:33:15.6 |     -0.809 |      0.721 |
# |         5 | 09:33:15.8 |     -0.622 |      0.824 |
# |         6 | 09:33:15.8 |     -0.437 |      0.909 |
# |         7 | 09:33:15.8 |     -0.245 |      0.971 |
# |         8 | 09:33:15.8 |     -0.028 |      1.000 |
# |         9 | 09:33:15.8 |      0.293 |      0.958 |
# |        10 | 09:33:15.8 |      0.705 |      0.780 |
# |        11 | 09:33:15.8 |      0.525 |      0.871 |
# |        12 | 09:33:15.8 |      0.763 |      0.747 |
# |        13 | 09:33:15.8 |      0.993 |      0.611 |
# |        14 | 09:33:15.8 |      0.932 |      0.648 |
# |        15 | 09:33:15.8 |      1.100 |      0.546 |
# |        16 | 09:33:15.8 |      1.268 |      0.448 |
# |        17 | 09:33:15.8 |      1.436 |      0.356 |
# |        18 | 09:33:15.8 |      1.608 |      0.274 |
# |        19 | 09:33:15.9 |      1.787 |      0.202 |
# |        20 | 09:33:15.9 |      1.980 |      0.141 |
# |        21 | 09:33:15.9 |      2.197 |      0.089 |
# |        22 | 09:33:15.9 |      2.456 |      0.049 |
# |        23 | 09:33:15.9 |      2.790 |      0.020 |
# |        24 | 09:33:15.9 |      3.292 |      0.004 |
# |        25 | 09:33:15.9 |      4.321 |      0.000 |
# |        26 | 09:33:15.9 |      6.545 |      0.000 |
# |        27 | 09:33:15.9 |      9.724 |      0.000 |
# +-----------+------------+------------+------------+
# generator adaptive_scan ['a35600cf'] (scan num: 8)
# ('a35600cf-06dc-41c0-8dec-305819b8addb',)

# %%
RE(
    adaptive_scan([det], 'det', motor, start=-10, stop=10, min_step=0.1, max_step=20, target_delta=0.001, backstep=True)
)
# Out:
# Transient Scan ID: 6     Time: 2024-08-28 09:33:02
# Persistent Unique Scan ID: '1587f20e-c580-445c-b7e7-e6dd9289759b'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |         1 | 09:33:02.2 |    -10.000 |      0.000 |
# |         2 | 09:33:02.2 |     -0.050 |      0.999 |
# |         3 | 09:33:02.2 |     -9.900 |      0.000 |
# |         4 | 09:33:02.3 |     -5.820 |      0.000 |
# |         5 | 09:33:02.3 |      1.444 |      0.353 |
# |         6 | 09:33:02.3 |     -5.720 |      0.000 |
# |         7 | 09:33:02.3 |     -1.640 |      0.261 |
# |         8 | 09:33:02.3 |     -5.620 |      0.000 |
# |         9 | 09:33:02.3 |     -1.540 |      0.306 |
# |        10 | 09:33:02.3 |     -5.520 |      0.000 |
# |        11 | 09:33:02.3 |     -1.440 |      0.355 |
# |        12 | 09:33:02.4 |     -5.420 |      0.000 |
# |        13 | 09:33:02.4 |     -1.340 |      0.407 |
# |        14 | 09:33:02.4 |     -5.320 |      0.000 |
# |        15 | 09:33:02.4 |     -1.240 |      0.464 |
# |        16 | 09:33:02.4 |     -5.220 |      0.000 |
# |        17 | 09:33:02.4 |     -1.140 |      0.522 |
# |        18 | 09:33:02.4 |     -5.120 |      0.000 |
# |        19 | 09:33:02.4 |     -1.040 |      0.582 |
# |        20 | 09:33:02.4 |     -5.020 |      0.000 |
# |        21 | 09:33:02.4 |     -0.940 |      0.643 |
# |        22 | 09:33:02.4 |     -4.920 |      0.000 |
# |        23 | 09:33:02.4 |     -0.840 |      0.703 |
# |        24 | 09:33:02.4 |     -4.820 |      0.000 |
# |        25 | 09:33:02.5 |     -0.740 |      0.760 |
# |        26 | 09:33:02.5 |     -4.720 |      0.000 |
# |        27 | 09:33:02.5 |     -1.012 |      0.599 |
# |        28 | 09:33:02.5 |     -4.620 |      0.000 |
# |        29 | 09:33:02.5 |     -2.228 |      0.084 |
# |        30 | 09:33:02.5 |     -4.520 |      0.000 |
# |        31 | 09:33:02.5 |     -2.951 |      0.013 |
# |        32 | 09:33:02.5 |     -4.398 |      0.000 |
# |        33 | 09:33:02.5 |     -3.379 |      0.003 |
# |        34 | 09:33:02.5 |     -4.085 |      0.000 |
# |        35 | 09:33:02.5 |     -3.477 |      0.002 |
# |        36 | 09:33:02.6 |     -3.800 |      0.001 |
# |        37 | 09:33:02.6 |     -3.456 |      0.003 |
# |        38 | 09:33:02.6 |     -3.610 |      0.001 |
# |        39 | 09:33:02.6 |     -3.408 |      0.003 |
# |        40 | 09:33:02.6 |     -3.478 |      0.002 |
# |        41 | 09:33:02.6 |     -3.342 |      0.004 |
# |        42 | 09:33:02.6 |     -3.378 |      0.003 |
# |        43 | 09:33:02.6 |     -3.277 |      0.005 |
# |        44 | 09:33:02.6 |     -3.177 |      0.006 |
# |        45 | 09:33:02.6 |     -3.076 |      0.009 |
# |        46 | 09:33:02.6 |     -2.976 |      0.012 |
# |        47 | 09:33:02.6 |     -2.876 |      0.016 |
# |        48 | 09:33:02.6 |     -2.775 |      0.021 |
# |        49 | 09:33:02.7 |     -2.675 |      0.028 |
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |        50 | 09:33:02.7 |     -2.575 |      0.036 |
# |        51 | 09:33:02.7 |     -2.475 |      0.047 |
# |        52 | 09:33:02.7 |     -2.375 |      0.060 |
# |        53 | 09:33:02.7 |     -2.275 |      0.075 |
# |        54 | 09:33:02.7 |     -2.175 |      0.094 |
# |        55 | 09:33:02.7 |     -2.075 |      0.116 |
# |        56 | 09:33:02.8 |     -1.975 |      0.142 |
# |        57 | 09:33:02.8 |     -1.875 |      0.173 |
# |        58 | 09:33:02.8 |     -1.775 |      0.207 |
# |        59 | 09:33:02.8 |     -1.675 |      0.246 |
# |        60 | 09:33:02.8 |     -1.575 |      0.290 |
# |        61 | 09:33:02.8 |     -1.475 |      0.337 |
# |        62 | 09:33:02.8 |     -1.374 |      0.389 |
# |        63 | 09:33:02.8 |     -1.274 |      0.444 |
# |        64 | 09:33:02.9 |     -1.174 |      0.502 |
# |        65 | 09:33:02.9 |     -1.074 |      0.561 |
# |        66 | 09:33:02.9 |     -0.974 |      0.622 |
# |        67 | 09:33:02.9 |     -0.874 |      0.682 |
# |        68 | 09:33:02.9 |     -0.774 |      0.741 |
# |        69 | 09:33:02.9 |     -0.674 |      0.797 |
# |        70 | 09:33:02.9 |     -0.574 |      0.848 |
# |        71 | 09:33:02.9 |     -0.474 |      0.894 |
# |        72 | 09:33:02.9 |     -0.374 |      0.932 |
# |        73 | 09:33:02.9 |     -0.274 |      0.963 |
# |        74 | 09:33:03.0 |     -0.174 |      0.985 |
# |        75 | 09:33:03.0 |     -0.074 |      0.997 |
# |        76 | 09:33:03.0 |      0.026 |      1.000 |
# |        77 | 09:33:03.0 |      0.126 |      0.992 |
# |        78 | 09:33:03.0 |      0.226 |      0.975 |
# |        79 | 09:33:03.0 |      0.326 |      0.948 |
# |        80 | 09:33:03.0 |      0.426 |      0.913 |
# |        81 | 09:33:03.0 |      0.526 |      0.871 |
# |        82 | 09:33:03.0 |      0.626 |      0.822 |
# |        83 | 09:33:03.1 |      0.726 |      0.769 |
# |        84 | 09:33:03.1 |      0.826 |      0.711 |
# |        85 | 09:33:03.1 |      0.926 |      0.652 |
# |        86 | 09:33:03.1 |      1.026 |      0.591 |
# |        87 | 09:33:03.1 |      1.126 |      0.531 |
# |        88 | 09:33:03.1 |      1.226 |      0.472 |
# |        89 | 09:33:03.1 |      1.326 |      0.415 |
# |        90 | 09:33:03.1 |      1.426 |      0.362 |
# |        91 | 09:33:03.1 |      1.526 |      0.312 |
# |        92 | 09:33:03.1 |      1.626 |      0.267 |
# |        93 | 09:33:03.2 |      1.726 |      0.226 |
# |        94 | 09:33:03.2 |      1.826 |      0.189 |
# |        95 | 09:33:03.2 |      1.926 |      0.157 |
# |        96 | 09:33:03.2 |      2.026 |      0.129 |
# |        97 | 09:33:03.2 |      2.126 |      0.104 |
# |        98 | 09:33:03.2 |      2.226 |      0.084 |
# |        99 | 09:33:03.2 |      2.326 |      0.067 |
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |       100 | 09:33:03.2 |      2.426 |      0.053 |
# |       101 | 09:33:03.2 |      2.526 |      0.041 |
# |       102 | 09:33:03.2 |      2.626 |      0.032 |
# |       103 | 09:33:03.2 |      2.726 |      0.024 |
# |       104 | 09:33:03.3 |      2.826 |      0.018 |
# |       105 | 09:33:03.3 |      2.926 |      0.014 |
# |       106 | 09:33:03.3 |      3.026 |      0.010 |
# |       107 | 09:33:03.3 |      3.126 |      0.008 |
# |       108 | 09:33:03.3 |      3.226 |      0.006 |
# |       109 | 09:33:03.4 |      3.326 |      0.004 |
# |       110 | 09:33:03.4 |      3.426 |      0.003 |
# |       111 | 09:33:03.4 |      3.526 |      0.002 |
# |       112 | 09:33:03.4 |      3.630 |      0.001 |
# |       113 | 09:33:03.4 |      3.746 |      0.001 |
# |       114 | 09:33:03.5 |      3.888 |      0.001 |
# |       115 | 09:33:03.5 |      4.077 |      0.000 |
# |       116 | 09:33:03.5 |      4.366 |      0.000 |
# |       117 | 09:33:03.5 |      4.930 |      0.000 |
# |       118 | 09:33:03.5 |      7.058 |      0.000 |
# +-----------+------------+------------+------------+
# generator adaptive_scan ['1587f20e'] (scan num: 6)
# ('1587f20e-c580-445c-b7e7-e6dd9289759b',)

# %%
from bluesky import RunEngine
from bluesky.plans import fly, adaptive_scan
from bluesky.callbacks.best_effort import BestEffortCallback
from ophyd.sim import flyer1, det, motor

# %%
RE = RunEngine()

bec = BestEffortCallback()
RE.subscribe(bec)
# Out:
# 0

# %% [markdown]
# ## Fly Scan

# %%
RE(
    fly([flyer1])
)
# Out:
# Transient Scan ID: 2     Time: 2024-08-26 15:31:42
# Persistent Unique Scan ID: 'baaad7c4-ab75-47de-91f4-788de79a2d3b'
# New stream: 'flyer1'
# ('baaad7c4-ab75-47de-91f4-788de79a2d3b',)

# %% [markdown]
# ## Adaptive Scan

# %%
RE(
    adaptive_scan([det], 'det', motor, start=-1, stop=10, min_step=0.1, max_step=7, target_delta=0.1, backstep=True)
)
# Out:
# Transient Scan ID: 6     Time: 2024-08-26 15:39:59
# Persistent Unique Scan ID: 'cfa8c5e0-d691-4037-9d44-b883d277503e'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |         1 | 15:39:59.6 |     -1.000 |      0.607 |
# |         2 | 15:39:59.7 |      2.450 |      0.050 |
# |         3 | 15:39:59.7 |     -0.380 |      0.930 |
# |         4 | 15:39:59.8 |     -0.809 |      0.721 |
# |         5 | 15:39:59.9 |     -0.622 |      0.824 |
# |         6 | 15:39:59.9 |     -0.437 |      0.909 |
# |         7 | 15:40:00.0 |     -0.245 |      0.971 |
# |         8 | 15:40:00.0 |     -0.028 |      1.000 |
# |         9 | 15:40:00.1 |      0.293 |      0.958 |
# |        10 | 15:40:00.1 |      0.705 |      0.780 |
# |        11 | 15:40:00.2 |      0.525 |      0.871 |
# |        12 | 15:40:00.3 |      0.763 |      0.747 |
# |        13 | 15:40:00.3 |      0.993 |      0.611 |
# |        14 | 15:40:00.4 |      0.932 |      0.648 |
# |        15 | 15:40:00.5 |      1.100 |      0.546 |
# |        16 | 15:40:00.5 |      1.268 |      0.448 |
# |        17 | 15:40:00.6 |      1.436 |      0.356 |
# |        18 | 15:40:00.7 |      1.608 |      0.274 |
# |        19 | 15:40:00.7 |      1.787 |      0.202 |
# |        20 | 15:40:00.8 |      1.980 |      0.141 |
# |        21 | 15:40:00.9 |      2.197 |      0.089 |
# |        22 | 15:40:00.9 |      2.456 |      0.049 |
# |        23 | 15:40:01.0 |      2.790 |      0.020 |
# |        24 | 15:40:01.0 |      3.292 |      0.004 |
# |        25 | 15:40:01.1 |      4.321 |      0.000 |
# |        26 | 15:40:01.2 |      6.545 |      0.000 |
# |        27 | 15:40:01.2 |      9.724 |      0.000 |
# +-----------+------------+------------+------------+
# generator adaptive_scan ['cfa8c5e0'] (scan num: 6)
# ('cfa8c5e0-d691-4037-9d44-b883d277503e',)

# %%
RE(
    adaptive_scan([det], 'det', motor, start=-10, stop=10, min_step=0.1, max_step=20, target_delta=0.001, backstep=True)
)
# Out:
# Transient Scan ID: 29     Time: 2024-08-26 15:45:10
# Persistent Unique Scan ID: '62d55257-795a-467c-ab63-9c019ff1f736'
# New stream: 'primary'
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |         1 | 15:45:10.5 |    -10.000 |      0.000 |
# |         2 | 15:45:10.6 |     -0.050 |      0.999 |
# |         3 | 15:45:10.6 |     -9.900 |      0.000 |
# |         4 | 15:45:10.7 |     -5.820 |      0.000 |
# |         5 | 15:45:10.8 |      1.444 |      0.353 |
# |         6 | 15:45:10.8 |     -5.614 |      0.000 |
# |         7 | 15:45:10.9 |     -1.449 |      0.350 |
# |         8 | 15:45:10.9 |     -5.495 |      0.000 |
# |         9 | 15:45:11.0 |     -1.400 |      0.375 |
# |        10 | 15:45:11.0 |     -5.386 |      0.000 |
# |        11 | 15:45:11.1 |     -1.299 |      0.430 |
# |        12 | 15:45:11.1 |     -5.286 |      0.000 |
# |        13 | 15:45:11.2 |     -1.206 |      0.483 |
# |        14 | 15:45:11.3 |     -5.186 |      0.000 |
# |        15 | 15:45:11.3 |     -1.106 |      0.543 |
# |        16 | 15:45:11.4 |     -5.086 |      0.000 |
# |        17 | 15:45:11.5 |     -1.006 |      0.603 |
# |        18 | 15:45:11.5 |     -4.986 |      0.000 |
# |        19 | 15:45:11.6 |     -0.906 |      0.663 |
# |        20 | 15:45:11.7 |     -4.886 |      0.000 |
# |        21 | 15:45:11.7 |     -0.806 |      0.723 |
# |        22 | 15:45:11.8 |     -4.786 |      0.000 |
# |        23 | 15:45:11.8 |     -0.706 |      0.779 |
# |        24 | 15:45:11.9 |     -4.686 |      0.000 |
# |        25 | 15:45:12.0 |     -0.606 |      0.832 |
# |        26 | 15:45:12.0 |     -4.586 |      0.000 |
# |        27 | 15:45:12.1 |     -0.506 |      0.880 |
# |        28 | 15:45:12.1 |     -4.486 |      0.000 |
# |        29 | 15:45:12.2 |     -0.406 |      0.921 |
# |        30 | 15:45:12.3 |     -4.386 |      0.000 |
# |        31 | 15:45:12.3 |     -0.306 |      0.954 |
# |        32 | 15:45:12.4 |     -4.286 |      0.000 |
# |        33 | 15:45:12.4 |     -0.206 |      0.979 |
# |        34 | 15:45:12.5 |     -4.186 |      0.000 |
# |        35 | 15:45:12.6 |     -0.411 |      0.919 |
# |        36 | 15:45:12.6 |     -4.086 |      0.000 |
# |        37 | 15:45:12.7 |     -1.515 |      0.317 |
# |        38 | 15:45:12.7 |     -3.986 |      0.000 |
# |        39 | 15:45:12.8 |     -2.209 |      0.087 |
# |        40 | 15:45:12.9 |     -3.781 |      0.001 |
# |        41 | 15:45:12.9 |     -2.668 |      0.028 |
# |        42 | 15:45:13.0 |     -3.379 |      0.003 |
# |        43 | 15:45:13.0 |     -2.740 |      0.023 |
# |        44 | 15:45:13.1 |     -3.062 |      0.009 |
# |        45 | 15:45:13.1 |     -2.700 |      0.026 |
# |        46 | 15:45:13.2 |     -2.848 |      0.017 |
# |        47 | 15:45:13.3 |     -2.624 |      0.032 |
# |        48 | 15:45:13.3 |     -2.695 |      0.026 |
# |        49 | 15:45:13.4 |     -2.539 |      0.040 |
# +-----------+------------+------------+------------+
# |   seq_num |       time |      motor |        det |
# +-----------+------------+------------+------------+
# |        50 | 15:45:13.4 |     -2.578 |      0.036 |
# |        51 | 15:45:13.7 |     -2.460 |      0.049 |
# |        52 | 15:45:13.8 |     -2.346 |      0.064 |
# |        53 | 15:45:13.8 |     -2.234 |      0.082 |
# |        54 | 15:45:13.9 |     -2.125 |      0.105 |
# |        55 | 15:45:14.0 |     -2.018 |      0.131 |
# |        56 | 15:45:14.1 |     -1.912 |      0.161 |
# |        57 | 15:45:14.2 |     -1.807 |      0.195 |
# |        58 | 15:45:14.2 |     -1.703 |      0.234 |
# |        59 | 15:45:14.3 |     -1.600 |      0.278 |
# |        60 | 15:45:14.4 |     -1.498 |      0.326 |
# |        61 | 15:45:14.5 |     -1.396 |      0.377 |
# |        62 | 15:45:14.5 |     -1.294 |      0.433 |
# |        63 | 15:45:14.6 |     -1.193 |      0.491 |
# |        64 | 15:45:14.6 |     -1.092 |      0.551 |
# |        65 | 15:45:14.7 |     -0.991 |      0.612 |
# |        66 | 15:45:14.8 |     -0.891 |      0.673 |
# |        67 | 15:45:14.8 |     -0.790 |      0.732 |
# |        68 | 15:45:14.9 |     -0.690 |      0.788 |
# |        69 | 15:45:14.9 |     -0.590 |      0.841 |
# |        70 | 15:45:15.0 |     -0.489 |      0.887 |
# |        71 | 15:45:15.1 |     -0.389 |      0.927 |
# |        72 | 15:45:15.1 |     -0.289 |      0.959 |
# |        73 | 15:45:15.2 |     -0.189 |      0.982 |
# |        74 | 15:45:15.3 |     -0.089 |      0.996 |
